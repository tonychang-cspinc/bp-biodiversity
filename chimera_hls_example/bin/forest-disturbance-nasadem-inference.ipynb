# %%
import os
os.environ['ACCOUNT_KEY'] = ""

# %%
import os
import tempfile
import urllib
import pandas as pd

temp_dir = tempfile.gettempdir()
# Storage locations are documented at http://aka.ms/ai4edata-nasadem
nasadem_account_name = 'nasadem'
nasadem_container_name = 'nasadem-nc'
nasadem_account_url = 'https://' + nasadem_account_name + '.blob.core.windows.net'
nasadem_blob_root = nasadem_account_url + '/' + nasadem_container_name + '/v001/'

# A full list of files is available at:
#
# https://nasademeuwest.blob.core.windows.net/nasadem-nc/v001/index/file_list.txt
nasadem_file_index_url = nasadem_blob_root + 'index/nasadem_file_list.txt'

nasadem_content_extension = '.nc'
nasadem_file_prefix = 'NASADEM_NC_'

# This will contain just the .nc files
nasadem_file_list = None
                                   
temp_dir = os.path.join(tempfile.gettempdir())
os.makedirs(temp_dir,exist_ok=True)

def download_url(url, destination_filename=None, progress_updater=None, force_download=False):
    """
    Download a URL to a temporary file
    """
    
    # This is not intended to guarantee uniqueness, we just know it happens to guarantee
    # uniqueness for this application.
    if destination_filename is None:
        url_as_filename = url.replace('://', '_').replace('/', '_')    
        destination_filename = \
            os.path.join(temp_dir,url_as_filename)
    if (not force_download) and (os.path.isfile(destination_filename)):
        print('Bypassing download of already-downloaded file {}'.format(
            os.path.basename(url)))
        return destination_filename
    print('Downloading file {} to {}'.format(os.path.basename(url),
                                             destination_filename),end='')
    urllib.request.urlretrieve(url, destination_filename, progress_updater)  
    assert(os.path.isfile(destination_filename))
    nBytes = os.path.getsize(destination_filename)
    print('...done, {} bytes.'.format(nBytes))
    return destination_filename


def lat_lon_to_nasadem_tile(lat,lon):
    """
    Get the NASADEM file name for a specified latitude and longitude
    """
    
    # A tile name looks like:
    #
    # NASADEM_NUMNC_n00e016.nc
    #
    # The translation from lat/lon to that string is represented nicely at:
    #
    # https://dwtkns.com/srtm30m/

    # Force download of the file list
    get_nasadem_file_list()
        
    ns_token = 'n' if lat >=0 else 's'
    ew_token = 'e' if lon >=0 else 'w'
    
    lat_index = abs(math.floor(lat))
    lon_index = abs(math.floor(lon))
    
    lat_string = ns_token + '{:02d}'.format(lat_index)
    lon_string = ew_token + '{:03d}'.format(lon_index)
    
    filename =  nasadem_file_prefix + lat_string + lon_string + \
        nasadem_content_extension

    if filename not in nasadem_file_list:
        print('Lat/lon {},{} not available'.format(lat,lon))
        filename = None
    
    return filename


def get_nasadem_file_list():
    """
    Retrieve the full list of NASADEM tiles
    """
    
    global nasadem_file_list
    if nasadem_file_list is None:
        nasadem_file = download_url(nasadem_file_index_url)
        with open(nasadem_file) as f:
            nasadem_file_list = f.readlines()
            nasadem_file_list = [f.strip() for f in nasadem_file_list]
            nasadem_file_list = [f for f in nasadem_file_list if \
                                 f.endswith(nasadem_content_extension)]
    return nasadem_file_list

def _get_hls_extents():
    hls_tile_extents_url = 'https://ai4edatasetspublicassets.blob.core.windows.net/assets/S2_TilingSystem2-1.txt?st=2019-08-23T03%3A25%3A57Z&se=2028-08-24T03%3A25%3A00Z&sp=rl&sv=2018-03-28&sr=b&sig=KHNZHIJuVG2KqwpnlsJ8truIT5saih8KrVj3f45ABKY%3D'
    # Load this file into a table, where each row is:
    # Tile ID, Xstart, Ystart, UZ, EPSG, MinLon, MaxLon, MinLat, MaxLat
    print('Reading HLS tile extents...')
    fp = temp_dir + '/hls_extents.csv'
    download_url(hls_tile_extents_url, fp)
    # s = requests.get(hls_tile_extents_url).content
    hls_tile_extents = pd.read_csv(fp, delimiter=r'\s+').set_index('TilID')
    print('Read HLS tile extents for {} tiles'.format(len(hls_tile_extents)))
    return hls_tile_extents

# %%
import math

import fsspec
import numpy as np
import richdem as rd
import rioxarray as rioxr
import xarray as xr
from rioxarray.merge import merge_datasets

def prepare_dataset(ds):
    """Takes a nasadem dataset with data variable elevation then:
        Calculates slope and cos(aspect) and normalizes them along with elevation to be in range [0, 1]
    """
    rd_arr = rd.rdarray(ds['elevation'].values, no_data=0)
    aspect = rd.TerrainAttribute(rd_arr, attrib='aspect')
    aspect[aspect < -9990] = 0.0
    # cos - range is -1 to 1 but we want 0 to 1
    aspect = (np.cos((aspect / 360) * 2 * math.pi) + 1) / 2
    # range is 0 to 90
    slp = rd.TerrainAttribute(rd_arr, attrib='slope_riserun')
    slp[slp < -9990] = 0.0
    # slope is 0 to 90, normal to [0-1]
    slp = slp / 90.0
    ds['slope'] = (['y', 'x'], slp)
    ds['aspect'] = (['y', 'x'], aspect)
    # normalize elevation to [0-1] (denali is 6190.5m in elevation, death valley is -86m)
    ds['elevation'] = (ds['elevation'] + 86.0) / (6190.5 - -86.0)
    return ds

def get_hls_nasadem(tile_name, hls_tile, extents):
    """Gets a dataset of nasadem data in the same CRS as the HLS tile and in the same bounds as the tile."""
    row = extents.loc[tile_name]
    daymets = []
    for lon in range(int(math.floor(row.MinLon)), int(math.trunc(row.MaxLon)+1)):
        for lat in range(int(math.floor(row.MinLat)), int(math.trunc(row.MaxLat)+1)):
            try:
                ds = xr.open_dataset(download_url(nasadem_blob_root + lat_lon_to_nasadem_tile(lat, lon))).rio.write_crs('EPSG:4326')
                ds = ds.rename({'lat': 'y', 'lon': 'x'})
                daymets.append(ds)
            except:
                pass
    return merge_datasets(daymets) \
      .fillna(0) \
      .transpose('y', 'x') \
      .rio.reproject(hls_tile.crs) \
      .rio.pad_box(*hls_tile.rio.bounds()) \
      .fillna(0) \
      .rio.clip_box(*hls_tile.rio.bounds()) \
      .rename({'NASADEM_HGT': 'elevation'})

def prep_nasadem_tile(tile_name, extents):
    path = fsspec.get_mapper(
        f"az://fia/hls/2018.0/{tile_name}.zarr",
        account_name="usfs",
        account_key=os.environ['ACCOUNT_KEY']
    )
    hls_tile = xr.open_zarr(path)
    ds = prepare_dataset(
        get_hls_nasadem(tile_name, hls_tile, extents)
    )
    output_path = fsspec.get_mapper(
        f"az://fia/nasadem/{tile_name}.zarr",
        account_name="usfs",
        account_key=os.environ['ACCOUNT_KEY']
    )
    ds.to_zarr(output_path, mode='w')
    return tile_name

# %%
catalog_path = fsspec.get_mapper(
    "az://fia/catalogs/hls_conus_2015-2019.zarr",
    account_name="usfs",
    account_key=os.environ['ACCOUNT_KEY']
)
catalog = xr.open_zarr(catalog_path)
tiles = sorted(set(catalog['tile'].values))
hls_extents = _get_hls_extents()
with open('nasadem_checkpoint', 'r') as f:
    checkpointed = f.read().split('\n')
with open('nasadem_checkpoint', 'a') as f:
    for tile in tiles:
        if tile in checkpointed:
            print(f"skipping checkpointed {tile}")
            continue
        try:
            print(prep_nasadem_tile(tile, hls_extents))
            f.write(f"{tile}\n")
        except Exception as e:
            print(e)
            print("FAILED", tile)
# Out:
# Reading HLS tile extents...
# Bypassing download of already-downloaded file S2_TilingSystem2-1.txt?st=2019-08-23T03%3A25%3A57Z&se=2028-08-24T03%3A25%3A00Z&sp=rl&sv=2018-03-28&sr=b&sig=KHNZHIJuVG2KqwpnlsJ8truIT5saih8KrVj3f45ABKY%3D
# Read HLS tile extents for 56686 tiles
# skipping checkpointed 10SDH
# skipping checkpointed 10SDJ
# skipping checkpointed 10SEF
# skipping checkpointed 10SEG
# skipping checkpointed 10SEH
# skipping checkpointed 10SEJ
# skipping checkpointed 10SFE
# skipping checkpointed 10SFF
# skipping checkpointed 10SFG
# skipping checkpointed 10SFH
# skipping checkpointed 10SFJ
# skipping checkpointed 10SGD
# skipping checkpointed 10SGE
# skipping checkpointed 10SGF
# skipping checkpointed 10SGG
# skipping checkpointed 10SGH
# skipping checkpointed 10SGJ
# skipping checkpointed 10TCK
# skipping checkpointed 10TCL
# skipping checkpointed 10TCM
# skipping checkpointed 10TCN
# skipping checkpointed 10TCP
# skipping checkpointed 10TCT
# skipping checkpointed 10TDK
# skipping checkpointed 10TDL
# skipping checkpointed 10TDM
# skipping checkpointed 10TDN
# skipping checkpointed 10TDP
# skipping checkpointed 10TDQ
# skipping checkpointed 10TDR
# skipping checkpointed 10TDS
# skipping checkpointed 10TDT
# skipping checkpointed 10TEK
# skipping checkpointed 10TEL
# skipping checkpointed 10TEM
# skipping checkpointed 10TEN
# skipping checkpointed 10TEP
# skipping checkpointed 10TEQ
# skipping checkpointed 10TER
# skipping checkpointed 10TES
# Downloading file nasadem_file_list.txt to /tmp/https_nasadem.blob.core.windows.net_nasadem-nc_v001_index_nasadem_file_list.txt...done, 1103520 bytes.
# Downloading file NASADEM_NC_n46w124.nc to /tmp/https_nasadem.blob.core.windows.net_nasadem-nc_v001_NASADEM_NC_n46w124.nc...done, 26000267 bytes.
# Downloading file NASADEM_NC_n47w124.nc to /tmp/https_nasadem.blob.core.windows.net_nasadem-nc_v001_NASADEM_NC_n47w124.nc...done, 26000267 bytes.
# Downloading file NASADEM_NC_n46w123.nc to /tmp/https_nasadem.blob.core.windows.net_nasadem-nc_v001_NASADEM_NC_n46w123.nc...done, 26000267 bytes.
# Downloading file NASADEM_NC_n47w123.nc to /tmp/https_nasadem.blob.core.windows.net_nasadem-nc_v001_NASADEM_NC_n47w123.nc...done, 26000267 bytes.
# Downloading file NASADEM_NC_n46w122.nc to /tmp/https_nasadem.blob.core.windows.net_nasadem-nc_v001_NASADEM_NC_n46w122.nc...done, 26000267 bytes.
# Downloading file NASADEM_NC_n47w122.nc to /tmp/https_nasadem.blob.core.windows.net_nasadem-nc_v001_NASADEM_NC_n47w122.nc...done, 26000267 bytes.
# Downloading file NASADEM_NC_n46w121.nc to /tmp/https_nasadem.blob.core.windows.net_nasadem-nc_v001_NASADEM_NC_n46w121.nc...done, 26000267 bytes.
# Downloading file NASADEM_NC_n47w121.nc to /tmp/https_nasadem.blob.core.windows.net_nasadem-nc_v001_NASADEM_NC_n47w121.nc...done, 26000267 bytes.
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 10TET
# skipping checkpointed 10TFK
# skipping checkpointed 10TFL
# skipping checkpointed 10TFM
# skipping checkpointed 10TFN
# skipping checkpointed 10TFP
# skipping checkpointed 10TFQ
# skipping checkpointed 10TFR
# skipping checkpointed 10TFS
# skipping checkpointed 10TFT
# skipping checkpointed 10TGK
# skipping checkpointed 10TGL
# skipping checkpointed 10TGM
# skipping checkpointed 10TGN
# skipping checkpointed 10TGP
# skipping checkpointed 10TGQ
# skipping checkpointed 10TGR
# skipping checkpointed 10TGS
# skipping checkpointed 10TGT
# skipping checkpointed 10UCU
# skipping checkpointed 10UDU
# skipping checkpointed 10UDV
# skipping checkpointed 10UEU
# skipping checkpointed 10UEV
# skipping checkpointed 10UFU
# skipping checkpointed 10UFV
# skipping checkpointed 10UGU
# skipping checkpointed 10UGV
# skipping checkpointed 11SKA
# skipping checkpointed 11SKB
# skipping checkpointed 11SKC
# skipping checkpointed 11SKD
# skipping checkpointed 11SKT
# skipping checkpointed 11SKU
# skipping checkpointed 11SKV
# skipping checkpointed 11SLA
# skipping checkpointed 11SLB
# skipping checkpointed 11SLC
# skipping checkpointed 11SLD
# skipping checkpointed 11SLT
# skipping checkpointed 11SLU
# skipping checkpointed 11SLV
# skipping checkpointed 11SMA
# skipping checkpointed 11SMB
# skipping checkpointed 11SMC
# skipping checkpointed 11SMD
# skipping checkpointed 11SMR
# skipping checkpointed 11SMS
# skipping checkpointed 11SMT
# skipping checkpointed 11SMU
# skipping checkpointed 11SMV
# skipping checkpointed 11SNA
# skipping checkpointed 11SNB
# skipping checkpointed 11SNC
# skipping checkpointed 11SND
# skipping checkpointed 11SNS
# skipping checkpointed 11SNT
# skipping checkpointed 11SNU
# skipping checkpointed 11SNV
# skipping checkpointed 11SPA
# skipping checkpointed 11SPB
# skipping checkpointed 11SPC
# skipping checkpointed 11SPD
# skipping checkpointed 11SPR
# skipping checkpointed 11SPS
# skipping checkpointed 11SPT
# skipping checkpointed 11SPU
# skipping checkpointed 11SPV
# skipping checkpointed 11SQA
# skipping checkpointed 11SQB
# skipping checkpointed 11SQC
# skipping checkpointed 11SQD
# skipping checkpointed 11SQR
# skipping checkpointed 11SQS
# skipping checkpointed 11SQT
# skipping checkpointed 11SQU
# skipping checkpointed 11SQV
# skipping checkpointed 11TKE
# skipping checkpointed 11TKF
# skipping checkpointed 11TKG
# skipping checkpointed 11TLE
# skipping checkpointed 11TLF
# skipping checkpointed 11TLG
# skipping checkpointed 11TLH
# skipping checkpointed 11TLJ
# skipping checkpointed 11TLK
# skipping checkpointed 11TLL
# skipping checkpointed 11TLM
# skipping checkpointed 11TLN
# skipping checkpointed 11TME
# skipping checkpointed 11TMF
# skipping checkpointed 11TMG
# skipping checkpointed 11TMH
# skipping checkpointed 11TMJ
# skipping checkpointed 11TMK
# skipping checkpointed 11TML
# skipping checkpointed 12TUP
# skipping checkpointed 12TUQ
# skipping checkpointed 12TUR
# skipping checkpointed 12TUS
# skipping checkpointed 12TUT
# skipping checkpointed 12TVK
# skipping checkpointed 12TVL
# skipping checkpointed 12TVM
# skipping checkpointed 12TVN
# skipping checkpointed 12TVP
# skipping checkpointed 12TVQ
# skipping checkpointed 12TVR
# skipping checkpointed 12TVS
# skipping checkpointed 12TVT
# skipping checkpointed 12TWK
# skipping checkpointed 12TWL
# skipping checkpointed 12TWM
# skipping checkpointed 12TWN
# skipping checkpointed 12TWP
# skipping checkpointed 12TWQ
# skipping checkpointed 12TWR
# skipping checkpointed 12TWS
# skipping checkpointed 12TWT
# skipping checkpointed 12TXK
# skipping checkpointed 12TXL
# skipping checkpointed 12TXM
# skipping checkpointed 12TXN
# skipping checkpointed 12TXP
# skipping checkpointed 12TXQ
# skipping checkpointed 12TXR
# skipping checkpointed 12TXS
# skipping checkpointed 12TXT
# skipping checkpointed 12TYK
# skipping checkpointed 12TYL
# skipping checkpointed 12TYM
# skipping checkpointed 12TYN
# skipping checkpointed 12TYP
# skipping checkpointed 12TYQ
# skipping checkpointed 12TYR
# skipping checkpointed 12TYS
# skipping checkpointed 12TYT
# skipping checkpointed 12UUU
# skipping checkpointed 12UUV
# skipping checkpointed 12UVU
# skipping checkpointed 12UVV
# skipping checkpointed 12UWU
# skipping checkpointed 12UWV
# skipping checkpointed 12UXU
# skipping checkpointed 12UXV
# skipping checkpointed 12UYU
# skipping checkpointed 12UYV
# skipping checkpointed 13RCQ
# skipping checkpointed 13RDP
# skipping checkpointed 13RDQ
# skipping checkpointed 13REN
# skipping checkpointed 13REP
# skipping checkpointed 13REQ
# skipping checkpointed 13RFN
# skipping checkpointed 13RFP
# skipping checkpointed 13RFQ
# skipping checkpointed 13RGN
# skipping checkpointed 13RGP
# skipping checkpointed 13RGQ
# skipping checkpointed 13SBA
# skipping checkpointed 13SBB
# skipping checkpointed 13SBC
# skipping checkpointed 13SBD
# skipping checkpointed 13SBR
# skipping checkpointed 13SBS
# skipping checkpointed 13SBT
# skipping checkpointed 13SBU
# skipping checkpointed 13SBV
# skipping checkpointed 13SCA
# skipping checkpointed 13SCB
# skipping checkpointed 13SCC
# skipping checkpointed 13SCD
# skipping checkpointed 13SCR
# skipping checkpointed 13SCS
# skipping checkpointed 13SCT
# skipping checkpointed 13SCU
# skipping checkpointed 13SCV
# skipping checkpointed 13SDA
# skipping checkpointed 13SDB
# skipping checkpointed 13SDC
# skipping checkpointed 13SDD
# skipping checkpointed 13SDR
# skipping checkpointed 13SDS
# skipping checkpointed 13SDT
# skipping checkpointed 13SDU
# skipping checkpointed 13SDV
# skipping checkpointed 13SEA
# skipping checkpointed 13SEB
# skipping checkpointed 13SEC
# skipping checkpointed 13SED
# skipping checkpointed 13SER
# skipping checkpointed 13SES
# skipping checkpointed 13SET
# skipping checkpointed 13SEU
# skipping checkpointed 13SEV
# skipping checkpointed 13SFA
# skipping checkpointed 13SFB
# skipping checkpointed 13SFC
# skipping checkpointed 13SFD
# skipping checkpointed 13SFR
# skipping checkpointed 13SFS
# skipping checkpointed 13SFT
# skipping checkpointed 16TCS
# skipping checkpointed 16TCT
# skipping checkpointed 16TDK
# skipping checkpointed 16TDL
# skipping checkpointed 16TDM
# skipping checkpointed 16TDN
# skipping checkpointed 16TDP
# skipping checkpointed 16TDQ
# skipping checkpointed 16TDR
# skipping checkpointed 16TDS
# skipping checkpointed 16TDT
# skipping checkpointed 16TEK
# skipping checkpointed 16TEL
# skipping checkpointed 16TEM
# skipping checkpointed 16TEN
# skipping checkpointed 16TEP
# skipping checkpointed 16TEQ
# skipping checkpointed 16TER
# skipping checkpointed 16TES
# skipping checkpointed 16TFK
# skipping checkpointed 16TFL
# skipping checkpointed 16TFM
# skipping checkpointed 16TFN
# skipping checkpointed 16TFP
# skipping checkpointed 16TFQ
# skipping checkpointed 16TFR
# skipping checkpointed 16TFS
# skipping checkpointed 16TGK
# skipping checkpointed 16TGL
# skipping checkpointed 16TGM
# skipping checkpointed 16TGN
# skipping checkpointed 16TGP
# skipping checkpointed 16TGQ
# skipping checkpointed 16TGR
# skipping checkpointed 16TGS
# skipping checkpointed 16UCU
# skipping checkpointed 17RKN
# skipping checkpointed 17RKP
# skipping checkpointed 17RKQ
# skipping checkpointed 17RLK
# skipping checkpointed 17RLL
# skipping checkpointed 17RLM
# skipping checkpointed 17RLN
# skipping checkpointed 17RLP
# skipping checkpointed 17RLQ
# skipping checkpointed 17RMH
# skipping checkpointed 17RMJ
# skipping checkpointed 17RMK
# skipping checkpointed 17RML
# skipping checkpointed 17RMM
# skipping checkpointed 17RMN
# skipping checkpointed 17RMP
# skipping checkpointed 17RMQ
# skipping checkpointed 17RNH
# skipping checkpointed 17RNJ
# skipping checkpointed 17RNK
# skipping checkpointed 17RNL
# skipping checkpointed 17RNM
# skipping checkpointed 17RNN
# skipping checkpointed 17SKA
# skipping checkpointed 17SKB
# skipping checkpointed 17SKC
# skipping checkpointed 17SKD
# skipping checkpointed 17SKR
# skipping checkpointed 17SKS
# skipping checkpointed 17SKT
# skipping checkpointed 17SKU
# skipping checkpointed 17SKV
# skipping checkpointed 17SLA
# skipping checkpointed 17SLB
# skipping checkpointed 17SLC
# skipping checkpointed 17SLD
# skipping checkpointed 17SLR
# skipping checkpointed 17SLS
# skipping checkpointed 17SLT
# skipping checkpointed 17SLU
# skipping checkpointed 17SLV
# skipping checkpointed 17SMA
# skipping checkpointed 17SMB
# skipping checkpointed 17SMC
# skipping checkpointed 17SMD
# skipping checkpointed 17SMR
# skipping checkpointed 17SMS
# skipping checkpointed 17SMT
# skipping checkpointed 17SMU
# skipping checkpointed 17SMV
# skipping checkpointed 17SNA
# skipping checkpointed 17SNB
# skipping checkpointed 17SNC
# skipping checkpointed 17SND
# skipping checkpointed 17SNR
# skipping checkpointed 17SNS
# skipping checkpointed 17SNT
# skipping checkpointed 17SNU
# skipping checkpointed 17SNV
# skipping checkpointed 17SPA
# skipping checkpointed 17SPB
# skipping checkpointed 17SPC
# skipping checkpointed 17SPD
# skipping checkpointed 17SPS
# skipping checkpointed 17SPT
# skipping checkpointed 17SPU
# skipping checkpointed 17SPV
# skipping checkpointed 17SQA
# skipping checkpointed 17SQB
# skipping checkpointed 17SQC
# skipping checkpointed 17SQD
# skipping checkpointed 17SQT
# skipping checkpointed 17SQU
# skipping checkpointed 17SQV
# skipping checkpointed 17TKE
# skipping checkpointed 17TKF
# skipping checkpointed 17TKG
# skipping checkpointed 17TLE
# skipping checkpointed 17TLF
# skipping checkpointed 17TLG
# skipping checkpointed 17TLH
# skipping checkpointed 17TLJ
# skipping checkpointed 17TLK
# skipping checkpointed 17TLL
# skipping checkpointed 17TLM
# skipping checkpointed 17TME
# skipping checkpointed 17TMF
# skipping checkpointed 17TMG
# skipping checkpointed 17TNE
# skipping checkpointed 17TNF
# skipping checkpointed 17TNG
# skipping checkpointed 17TPE
# skipping checkpointed 17TPF
# skipping checkpointed 17TPG
# skipping checkpointed 17TPH
# skipping checkpointed 17TPJ
# skipping checkpointed 17TQE
# skipping checkpointed 17TQF
# skipping checkpointed 17TQG
# skipping checkpointed 17TQH
# skipping checkpointed 17TQJ
# skipping checkpointed 18STC
# skipping checkpointed 18STD
# skipping checkpointed 18STE
# skipping checkpointed 18STF
# skipping checkpointed 18STG
# skipping checkpointed 18STH
# skipping checkpointed 18STJ
# skipping checkpointed 18SUD
# skipping checkpointed 18SUE
# skipping checkpointed 18SUF
# skipping checkpointed 18SUG
# skipping checkpointed 18SUH
# skipping checkpointed 18SUJ
# skipping checkpointed 18SVD
# skipping checkpointed 18SVE
# skipping checkpointed 18SVF
# skipping checkpointed 18SVG
# skipping checkpointed 18SVH
# skipping checkpointed 18SVJ
# skipping checkpointed 18SWJ
# skipping checkpointed 18TTK
# skipping checkpointed 18TTL
# skipping checkpointed 18TTM
# skipping checkpointed 18TUK
# skipping checkpointed 18TUL
# skipping checkpointed 18TUM
# skipping checkpointed 18TUN
# skipping checkpointed 18TUP
# skipping checkpointed 18TUQ
# skipping checkpointed 18TVK
# skipping checkpointed 18TVL
# skipping checkpointed 18TVM
# skipping checkpointed 18TVN
# skipping checkpointed 18TVP
# skipping checkpointed 18TVQ
# skipping checkpointed 18TWK
# skipping checkpointed 18TWL
# skipping checkpointed 18TWM
# skipping checkpointed 18TWN
# skipping checkpointed 18TWP
# skipping checkpointed 18TWQ
# skipping checkpointed 18TXL
# skipping checkpointed 18TXM
# skipping checkpointed 18TXN
# skipping checkpointed 18TXP
# skipping checkpointed 18TXQ
# skipping checkpointed 18TYL
# skipping checkpointed 18TYM
# skipping checkpointed 18TYN
# skipping checkpointed 18TYP
# skipping checkpointed 18TYQ
# skipping checkpointed 18TYR
# skipping checkpointed 19TBF
# skipping checkpointed 19TBG
# skipping checkpointed 19TCF
# skipping checkpointed 19TCG
# skipping checkpointed 19TCH
# skipping checkpointed 19TCJ
# skipping checkpointed 19TCK
# skipping checkpointed 19TCL
# skipping checkpointed 19TCM
# skipping checkpointed 19TDG
# skipping checkpointed 19TDJ
# skipping checkpointed 19TDK
# skipping checkpointed 19TDL
# skipping checkpointed 19TDM
# skipping checkpointed 19TDN
# skipping checkpointed 19TEK
# skipping checkpointed 19TEL
# skipping checkpointed 19TEM
# skipping checkpointed 19TEN
# skipping checkpointed 19TFK
# skipping checkpointed 19TFL
