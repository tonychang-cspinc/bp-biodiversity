# %%
import os

# pip/conda installed
import fsspec

from utils import get_logger
from utils.hls.catalog import HLSCatalog
from utils.hls.compute import process_jobs
from utils.hls.compute import jobs_from_catalog
from utils.hls.compute import calculate_job_median

# %%
logger = get_logger('hls-west')
cluster_args = dict(
    workers=64,
    worker_threads=1,
    worker_memory=8,
    scheduler_threads=4,
    scheduler_memory=8
)
code_path = './utils'

# %%
# fill with your account key
os.environ['AZURE_ACCOUNT_KEY'] = ""

# %%
catalog_url = fsspec.get_mapper(
    f"az://fia/catalogs/hls_west_2015-2019.zarr",
    account_name="usfs",
    account_key=os.environ['AZURE_ACCOUNT_KEY']
)
catalog = HLSCatalog.from_zarr(catalog_url)

# %%
# kwargs for calculate_job_median
account_name = "usfs"
storage_container = "fia/hls"
account_key = os.environ["AZURE_ACCOUNT_KEY"]
job_groupby = "time.month"
bands = catalog.xr_ds.attrs['bands']
chunks = {'band': 1, 'x': 3660, 'y': 3660} # read an entire tile once (each tile is 3660x3660)

# %%
# Filter to scenes from 2015 and later, then group by year
yr_catalogs = catalog.xr_ds.where(catalog.xr_ds['year'] >= 2015, drop=True).groupby('year')

# catalog -> job args
catalog_groupby = "tile"

# %%
for yr, ca in yr_catalogs:
    logger.info(f"Starting process for {yr}")
    ca.info()
    storage_prefix = f"{storage_container}/{yr}"
    checkpoint_path = f"checkpoints/{yr}.txt"
    jobs = jobs_from_catalog(ca, catalog_groupby)
    process_jobs(
        jobs=jobs,
        job_fn=calculate_job_median,
        checkpoint_path=checkpoint_path,
        logger=logger,
        cluster_args=cluster_args,
        code_path=code_path,
        concurrency=2,  # run 2 jobs at once
        cluster_restart_freq=16,  # restart after 16 jobs
        # kwargs for calculate_job_median
        job_groupby=job_groupby,
        bands=bands,
        chunks=chunks,
        account_name=account_name,
        storage_container=storage_prefix,
        account_key=account_key,
    )
# Out:
# 2021-01-28 01:18:19,243 [INFO] hls-west - Starting process for 2015.0
# xarray.Dataset {
# dimensions:
# 	index = 23159 ;
#
# variables:
# 	datetime64[ns] dt(index) ;
# 	object scene(index) ;
# 	object sensor(index) ;
# 	object tile(index) ;
# 	float64 year(index) ;
# 	int64 index(index) ;
#
# // global attributes:
# 	:bands = [<HLSBand.COASTAL_AEROSOL: 1>, <HLSBand.BLUE: 2>, <HLSBand.GREEN: 3>, <HLSBand.RED: 4>, <HLSBand.NIR_NARROW: 5>, <HLSBand.SWIR1: 6>, <HLSBand.SWIR2: 7>, <HLSBand.CIRRUS: 8>, <HLSBand.QA: 11>] ;
# }2021-01-28 01:18:20,274 [INFO] hls-west - Skipping checkpointed job 10SDH
# 2021-01-28 01:18:20,275 [INFO] hls-west - Skipping checkpointed job 10SDJ
# 2021-01-28 01:18:20,276 [INFO] hls-west - Skipping checkpointed job 10SEF
# 2021-01-28 01:18:20,276 [INFO] hls-west - Skipping checkpointed job 10SEG
# 2021-01-28 01:18:20,277 [INFO] hls-west - Skipping checkpointed job 10SEH
# 2021-01-28 01:18:31,792 [INFO] hls-west - Cluster dashboard visible at /services/dask-gateway/clusters/default.68aa3552cc7e44f7add130fc75869576/status
# 2021-01-28 01:18:31,820 [INFO] hls-west - Uploading code to cluster
# 2021-01-28 01:18:31,822 [INFO] hls-west - Submitting job 11SLB
# 2021-01-28 01:18:31,824 [INFO] hls-west - Submitting job 11UPQ
# 2021-01-28 01:18:48,291 [ERROR] hls-west - Exception from dask cluster
# Traceback (most recent call last):
#   File "/home/jovyan/data-ingestion/utils/hls/compute.py", line 249, in run_job_subset
#     result = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 224, in result
#     raise exc.with_traceback(tb)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-ii1e9v6g/source.zip/utils/hls/compute.py", line 177, in calculate_job_median
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/base.py", line 567, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 2676, in get
#     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1985, in gather
#     return self.sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 831, in sync
#     return sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 340, in sync
#     raise exc.with_traceback(tb)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 324, in f
#     result[0] = yield future
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/tornado/gen.py", line 762, in run
#     value = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1850, in _gather
#     raise exception.with_traceback(traceback)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/utils.py", line 30, in apply
#     return func(*args, **kwargs)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-ii1e9v6g/source.zip/utils/hls/compute.py", line 86, in get_scene_dataset
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/base.py", line 567, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 2676, in get
#     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1985, in gather
#     return self.sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 831, in sync
#     return sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 340, in sync
#     raise exc.with_traceback(tb)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 324, in f
#     result[0] = yield future
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/tornado/gen.py", line 762, in run
#     value = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1850, in _gather
#     raise exception.with_traceback(traceback)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/utils.py", line 30, in apply
#     return func(*args, **kwargs)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-ii1e9v6g/source.zip/utils/hls/compute.py", line 52, in fetch_band_url
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/rasterio_.py", line 242, in open_rasterio
#     riods = manager.acquire()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/file_manager.py", line 181, in acquire
#     file, _ = self._acquire_with_cache_info(needs_lock)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/file_manager.py", line 205, in _acquire_with_cache_info
#     file = self._opener(*self._args, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/rasterio/env.py", line 435, in wrapper
#     return f(*args, **kwds)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/rasterio/__init__.py", line 207, in open
#     s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#   File "rasterio/_base.pyx", line 262, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
# 2021-01-28 01:18:48,294 [INFO] hls-west - Submitting job 12TYM
# 2021-01-28 01:18:57,794 [ERROR] hls-west - Exception from dask cluster
# Traceback (most recent call last):
#   File "/home/jovyan/data-ingestion/utils/hls/compute.py", line 249, in run_job_subset
#     result = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 224, in result
#     raise exc.with_traceback(tb)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-s5isgvnj/source.zip/utils/hls/compute.py", line 177, in calculate_job_median
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/base.py", line 567, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 2676, in get
#     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1985, in gather
#     return self.sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 831, in sync
#     return sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 340, in sync
#     raise exc.with_traceback(tb)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 324, in f
#     result[0] = yield future
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/tornado/gen.py", line 762, in run
#     value = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1850, in _gather
#     raise exception.with_traceback(traceback)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/utils.py", line 30, in apply
#     return func(*args, **kwargs)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-s5isgvnj/source.zip/utils/hls/compute.py", line 86, in get_scene_dataset
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/base.py", line 567, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 2676, in get
#     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1985, in gather
#     return self.sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 831, in sync
#     return sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 340, in sync
#     raise exc.with_traceback(tb)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 324, in f
#     result[0] = yield future
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/tornado/gen.py", line 762, in run
#     value = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1850, in _gather
#     raise exception.with_traceback(traceback)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/utils.py", line 30, in apply
#     return func(*args, **kwargs)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-s5isgvnj/source.zip/utils/hls/compute.py", line 52, in fetch_band_url
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/rasterio_.py", line 242, in open_rasterio
#     riods = manager.acquire()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/file_manager.py", line 181, in acquire
#     file, _ = self._acquire_with_cache_info(needs_lock)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/file_manager.py", line 205, in _acquire_with_cache_info
#     file = self._opener(*self._args, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/rasterio/env.py", line 435, in wrapper
#     return f(*args, **kwds)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/rasterio/__init__.py", line 207, in open
#     s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#   File "rasterio/_base.pyx", line 262, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
# 2021-01-28 01:19:00,076 [ERROR] hls-west - Exception from dask cluster
# Traceback (most recent call last):
#   File "/home/jovyan/data-ingestion/utils/hls/compute.py", line 249, in run_job_subset
#     result = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 224, in result
#     raise exc.with_traceback(tb)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-zfeu8spe/source.zip/utils/hls/compute.py", line 177, in calculate_job_median
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/base.py", line 567, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 2676, in get
#     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1985, in gather
#     return self.sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 831, in sync
#     return sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 340, in sync
#     raise exc.with_traceback(tb)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 324, in f
#     result[0] = yield future
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/tornado/gen.py", line 762, in run
#     value = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1850, in _gather
#     raise exception.with_traceback(traceback)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/utils.py", line 30, in apply
#     return func(*args, **kwargs)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-zfeu8spe/source.zip/utils/hls/compute.py", line 86, in get_scene_dataset
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/base.py", line 567, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 2676, in get
#     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1985, in gather
#     return self.sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 831, in sync
#     return sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 340, in sync
#     raise exc.with_traceback(tb)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 324, in f
#     result[0] = yield future
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/tornado/gen.py", line 762, in run
#     value = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1850, in _gather
#     raise exception.with_traceback(traceback)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/utils.py", line 30, in apply
#     return func(*args, **kwargs)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-zfeu8spe/source.zip/utils/hls/compute.py", line 52, in fetch_band_url
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/rasterio_.py", line 242, in open_rasterio
#     riods = manager.acquire()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/file_manager.py", line 181, in acquire
#     file, _ = self._acquire_with_cache_info(needs_lock)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/file_manager.py", line 205, in _acquire_with_cache_info
#     file = self._opener(*self._args, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/rasterio/env.py", line 435, in wrapper
#     return f(*args, **kwds)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/rasterio/__init__.py", line 207, in open
#     s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#   File "rasterio/_base.pyx", line 262, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
# 2021-01-28 01:19:00,129 [INFO] hls-west - Metrics: {"job_errors": 3, "job_skips": 424, "job_completes": 0, "time": 39.85764452908188}
# 2021-01-28 01:19:00,165 [INFO] hls-west - Starting process for 2016.0
# xarray.Dataset {
# dimensions:
# 	index = 38325 ;
#
# variables:
# 	datetime64[ns] dt(index) ;
# 	object scene(index) ;
# 	object sensor(index) ;
# 	object tile(index) ;
# 	float64 year(index) ;
# 	int64 index(index) ;
#
# // global attributes:
# 	:bands = [<HLSBand.COASTAL_AEROSOL: 1>, <HLSBand.BLUE: 2>, <HLSBand.GREEN: 3>, <HLSBand.RED: 4>, <HLSBand.NIR_NARROW: 5>, <HLSBand.SWIR1: 6>, <HLSBand.SWIR2: 7>, <HLSBand.CIRRUS: 8>, <HLSBand.QA: 11>] ;
# }2021-01-28 01:19:01,534 [INFO] hls-west - Skipping checkpointed job 10SDH
# 2021-01-28 01:19:01,535 [INFO] hls-west - Skipping checkpointed job 10SDJ
# 2021-01-28 01:19:01,536 [INFO] hls-west - Skipping checkpointed job 10SEF
# 2021-01-28 01:19:01,536 [INFO] hls-west - Skipping checkpointed job 10SEG
# 2021-01-28 01:19:01,536 [INFO] hls-west - Skipping checkpointed job 10SEH
# 2021-01-28 01:19:01,537 [INFO] hls-west - Skipping checkpointed job 10SEJ
# 2021-01-28 01:19:01,537 [INFO] hls-west - Skipping checkpointed job 10SFE
# 2021-01-28 01:19:01,538 [INFO] hls-west - Skipping checkpointed job 10SFF
# 2021-01-28 01:19:01,539 [INFO] hls-west - Skipping checkpointed job 10SFG
# 2021-01-28 01:19:01,540 [INFO] hls-west - Skipping checkpointed job 10SFH
# 2021-01-28 01:19:01,540 [INFO] hls-west - Skipping checkpointed job 10SFJ
# 2021-01-28 01:19:01,541 [INFO] hls-west - Skipping checkpointed job 10SGD
# 2021-01-28 01:19:01,541 [INFO] hls-west - Skipping checkpointed job 10SGE
# 2021-01-28 01:19:01,542 [INFO] hls-west - Skipping checkpointed job 10SGF
# 2021-01-28 01:19:01,542 [INFO] hls-west - Skipping checkpointed job 10SGG
# 2021-01-28 01:19:01,542 [INFO] hls-west - Skipping checkpointed job 10SGH
# 2021-01-28 01:19:01,543 [INFO] hls-west - Skipping checkpointed job 10SGJ
# 2021-01-28 01:19:01,543 [INFO] hls-west - Skipping checkpointed job 10TCK
# 2021-01-28 01:19:01,543 [INFO] hls-west - Skipping checkpointed job 10TCL
# 2021-01-28 01:19:01,544 [INFO] hls-west - Skipping checkpointed job 10TCM
# 2021-01-28 01:19:01,544 [INFO] hls-west - Skipping checkpointed job 10TCN
# 2021-01-28 01:19:01,545 [INFO] hls-west - Skipping checkpointed job 10TCP
# 2021-01-28 01:19:01,545 [INFO] hls-west - Skipping checkpointed job 10TCQ
# 2021-01-28 01:19:01,545 [INFO] hls-west - Skipping checkpointed job 10TCT
# 2021-01-28 01:19:01,546 [INFO] hls-west - Skipping checkpointed job 10TDK
# 2021-01-28 01:19:01,546 [INFO] hls-west - Skipping checkpointed job 10TDL
# 2021-01-28 01:19:01,546 [INFO] hls-west - Skipping checkpointed job 10TDM
# 2021-01-28 01:19:01,547 [INFO] hls-west - Skipping checkpointed job 10TDN
# 2021-01-28 01:19:01,549 [INFO] hls-west - Skipping checkpointed job 10TDP
# 2021-01-28 01:19:01,549 [INFO] hls-west - Skipping checkpointed job 10TDQ
# 2021-01-28 01:19:01,549 [INFO] hls-west - Skipping checkpointed job 10TDR
# 2021-01-28 01:19:01,550 [INFO] hls-west - Skipping checkpointed job 10TDS
# 2021-01-28 01:19:01,550 [INFO] hls-west - Skipping checkpointed job 10TDT
# ...
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 324, in f
#     result[0] = yield future
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/tornado/gen.py", line 762, in run
#     value = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1850, in _gather
#     raise exception.with_traceback(traceback)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/utils.py", line 30, in apply
#     return func(*args, **kwargs)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-2ae4fxc9/source.zip/utils/hls/compute.py", line 86, in get_scene_dataset
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/base.py", line 567, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 2676, in get
#     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1985, in gather
#     return self.sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 831, in sync
#     return sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 340, in sync
#     raise exc.with_traceback(tb)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 324, in f
#     result[0] = yield future
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/tornado/gen.py", line 762, in run
#     value = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1850, in _gather
#     raise exception.with_traceback(traceback)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/utils.py", line 30, in apply
#     return func(*args, **kwargs)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-2ae4fxc9/source.zip/utils/hls/compute.py", line 52, in fetch_band_url
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/rasterio_.py", line 242, in open_rasterio
#     riods = manager.acquire()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/file_manager.py", line 181, in acquire
#     file, _ = self._acquire_with_cache_info(needs_lock)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/file_manager.py", line 205, in _acquire_with_cache_info
#     file = self._opener(*self._args, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/rasterio/env.py", line 435, in wrapper
#     return f(*args, **kwds)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/rasterio/__init__.py", line 207, in open
#     s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#   File "rasterio/_base.pyx", line 262, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
# 2021-01-28 01:28:52,439 [INFO] hls-west - Submitting job 12UXV
# 2021-01-28 01:29:00,144 [ERROR] hls-west - Exception from dask cluster
# Traceback (most recent call last):
#   File "/home/jovyan/data-ingestion/utils/hls/compute.py", line 249, in run_job_subset
#     result = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 224, in result
#     raise exc.with_traceback(tb)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-uaqzve8u/source.zip/utils/hls/compute.py", line 177, in calculate_job_median
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/base.py", line 567, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 2676, in get
#     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1985, in gather
#     return self.sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 831, in sync
#     return sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 340, in sync
#     raise exc.with_traceback(tb)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 324, in f
#     result[0] = yield future
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/tornado/gen.py", line 762, in run
#     value = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1850, in _gather
#     raise exception.with_traceback(traceback)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/utils.py", line 30, in apply
#     return func(*args, **kwargs)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-uaqzve8u/source.zip/utils/hls/compute.py", line 86, in get_scene_dataset
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/base.py", line 567, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 2676, in get
#     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1985, in gather
#     return self.sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 831, in sync
#     return sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 340, in sync
#     raise exc.with_traceback(tb)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 324, in f
#     result[0] = yield future
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/tornado/gen.py", line 762, in run
#     value = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1850, in _gather
#     raise exception.with_traceback(traceback)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/utils.py", line 30, in apply
#     return func(*args, **kwargs)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-uaqzve8u/source.zip/utils/hls/compute.py", line 52, in fetch_band_url
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/rasterio_.py", line 242, in open_rasterio
#     riods = manager.acquire()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/file_manager.py", line 181, in acquire
#     file, _ = self._acquire_with_cache_info(needs_lock)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/file_manager.py", line 205, in _acquire_with_cache_info
#     file = self._opener(*self._args, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/rasterio/env.py", line 435, in wrapper
#     return f(*args, **kwds)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/rasterio/__init__.py", line 207, in open
#     s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#   File "rasterio/_base.pyx", line 262, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
# 2021-01-28 01:29:00,145 [INFO] hls-west - Submitting job 13TGJ
# 2021-01-28 01:29:06,958 [ERROR] hls-west - Exception from dask cluster
# Traceback (most recent call last):
#   File "/home/jovyan/data-ingestion/utils/hls/compute.py", line 249, in run_job_subset
#     result = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 224, in result
#     raise exc.with_traceback(tb)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-cl454dtp/source.zip/utils/hls/compute.py", line 177, in calculate_job_median
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/base.py", line 567, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 2676, in get
#     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1985, in gather
#     return self.sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 831, in sync
#     return sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 340, in sync
#     raise exc.with_traceback(tb)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 324, in f
#     result[0] = yield future
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/tornado/gen.py", line 762, in run
#     value = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1850, in _gather
#     raise exception.with_traceback(traceback)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/utils.py", line 30, in apply
#     return func(*args, **kwargs)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-cl454dtp/source.zip/utils/hls/compute.py", line 86, in get_scene_dataset
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/base.py", line 567, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 2676, in get
#     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1985, in gather
#     return self.sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 831, in sync
#     return sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 340, in sync
#     raise exc.with_traceback(tb)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 324, in f
#     result[0] = yield future
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/tornado/gen.py", line 762, in run
#     value = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1850, in _gather
#     raise exception.with_traceback(traceback)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/utils.py", line 30, in apply
#     return func(*args, **kwargs)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-cl454dtp/source.zip/utils/hls/compute.py", line 52, in fetch_band_url
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/rasterio_.py", line 242, in open_rasterio
#     riods = manager.acquire()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/file_manager.py", line 181, in acquire
#     file, _ = self._acquire_with_cache_info(needs_lock)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/file_manager.py", line 205, in _acquire_with_cache_info
#     file = self._opener(*self._args, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/rasterio/env.py", line 435, in wrapper
#     return f(*args, **kwds)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/rasterio/__init__.py", line 207, in open
#     s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#   File "rasterio/_base.pyx", line 262, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
# 2021-01-28 01:29:54,175 [ERROR] hls-west - Exception from dask cluster
# Traceback (most recent call last):
#   File "/home/jovyan/data-ingestion/utils/hls/compute.py", line 249, in run_job_subset
#     result = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 224, in result
#     raise exc.with_traceback(tb)
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-lwmk_xha/source.zip/utils/hls/compute.py", line 188, in calculate_job_median
#   File "/home/jovyan/dask-worker-space/dask-worker-space/worker-lwmk_xha/source.zip/utils/hls/compute.py", line 133, in save_to_zarr
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/core/dataset.py", line 1745, in to_zarr
#     return to_zarr(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/api.py", line 1482, in to_zarr
#     writes = writer.sync(compute=compute)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/common.py", line 155, in sync
#     delayed_store = da.store(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/array/core.py", line 1021, in store
#     result.compute(**kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/base.py", line 279, in compute
#     (result,) = compute(self, traverse=False, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/base.py", line 567, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 2676, in get
#     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1985, in gather
#     return self.sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 831, in sync
#     return sync(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 340, in sync
#     raise exc.with_traceback(tb)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/utils.py", line 324, in f
#     result[0] = yield future
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/tornado/gen.py", line 762, in run
#     value = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/client.py", line 1850, in _gather
#     raise exception.with_traceback(traceback)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/dask/array/core.py", line 105, in getter
#     c = np.asarray(c)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/core/indexing.py", line 503, in __array__
#     return np.asarray(self.array, dtype=dtype)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/core/indexing.py", line 663, in __array__
#     return np.asarray(self.array, dtype=dtype)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/core/indexing.py", line 568, in __array__
#     return np.asarray(array[self.key], dtype=None)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/rasterio_.py", line 130, in __getitem__
#     return indexing.explicit_indexing_adapter(
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/core/indexing.py", line 853, in explicit_indexing_adapter
#     result = raw_indexing_method(raw_key.tuple)
#   File "/srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/backends/rasterio_.py", line 123, in _getitem
#     out = riods.read(band_key, window=window)
#   File "rasterio/_io.pyx", line 359, in rasterio._io.DatasetReaderBase.read
#   File "rasterio/_io.pyx", line 698, in rasterio._io.DatasetReaderBase._read
# rasterio.errors.RasterioIOError: Read or write failed. /vsicurl/https://hlssa.blob.core.windows.net/hls/S30/HLS.S30.T13TGJ.2019009.v1.4_01.tif, band 1: IReadBlock failed at X offset 0, Y offset 0: TIFFReadEncodedTile() failed.
# 2021-01-28 01:29:54,226 [INFO] hls-west - Metrics: {"job_errors": 12, "job_skips": 415, "job_completes": 0, "time": 182.77073369803838}
